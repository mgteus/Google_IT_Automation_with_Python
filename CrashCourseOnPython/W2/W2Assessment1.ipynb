# %% [markdown]
# #**Module 2 Graded Assessment**
# Grade 10/10

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'big'>'small'
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
11%5
# Out:
# 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
((10 >= 5*2) and (10 <= 5*2))
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(5/4)%1
# Out:
# 0.25

# %% [markdown]
# #**GRADE:**10/10
